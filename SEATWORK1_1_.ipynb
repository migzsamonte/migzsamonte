# %% [markdown]
# <a href="https://colab.research.google.com/github/migzsamonte/migzsamonte/blob/main/SEATWORK1_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.

# %%
def calculate_grade(exam, hoa, quiz, assignment, weight_exam, weight_hoa, weight_quiz, weight_assignment):
    """Calculates a grade component (CS or Grade) based on given scores and weights."""
    class_standing = (weight_hoa * hoa) + (weight_quiz * quiz) + (weight_assignment * assignment)
    grade = (weight_exam * exam) + (weight_exam * class_standing)  # exam weight is also 50%
    return grade

def calculate_weighted_average(grade1, grade2, weight1, weight2):
    """Calculates a weighted average of two grades."""
    return (weight1 * grade1) + (weight2 * grade2)

# Input scores
prelim_exam = float(input("Enter prelim exam score: "))
prelim_hoa = float(input("Enter average prelim HOA score: "))
prelim_quiz = float(input("Enter average prelim quiz score: "))
prelim_assignment = float(input("Enter average prelim assignment score: "))

midterm_exam = float(input("Enter midterm exam score: "))
midterm_hoa = float(input("Enter average midterm HOA score: "))
midterm_quiz = float(input("Enter average midterm quiz score: "))
midterm_assignment = float(input("Enter average midterm assignment score: "))

final_exam = float(input("Enter final exam score: "))
final_hoa = float(input("Enter average final HOA score: "))
final_quiz = float(input("Enter average final quiz score: "))
final_assignment = float(input("Enter average final assignment score: "))


# Calculation of Prelim Grade
prelim_grade = calculate_grade(prelim_exam, prelim_hoa, prelim_quiz, prelim_assignment, 0.5, 0.5, 0.3, 0.2)

# Calculation of Midterm Grade
midterm_cs = calculate_grade(midterm_exam, midterm_hoa, midterm_quiz, midterm_assignment, 0.5, 0.5, 0.3, 0.2)
midterm_grade = calculate_weighted_average(prelim_grade, midterm_cs, 1/3, 2/3)

# Calculation of Final Grade
final_cs = calculate_grade(final_exam, final_hoa, final_quiz, final_assignment, 0.5, 0.5, 0.3, 0.2)
final_grade = calculate_weighted_average(midterm_grade, final_cs, 1/3, 2/3)


print("Prelim Grade:", prelim_grade)
print("Midterm Grade:", midterm_grade)
print("Final Grade:", final_grade)
# Out:
# Enter prelim exam score: 35
# Enter average prelim HOA score: 26.1
# Enter average prelim quiz score: 50.0
# Enter average prelim assignment score: 20.0
# Enter midterm exam score: 24
# Enter average midterm HOA score: 27
# Enter average midterm quiz score: 45
# Enter average midterm assignment score: 19
# Enter final exam score: 29
# Enter average final HOA score: 27
# Enter average final quiz score: 48
# Enter average final assignment score: 20
# Prelim Grade: 33.525
# Midterm Grade: 29.441666666666663
# Final Grade: 30.113888888888884

# %% [markdown]
# SUPPLEMENTARY ACTIVITY

# %%
def calculate_grade(exam, hoa, quiz, assignment, weight_exam, weight_hoa, weight_quiz, weight_assignment):
    """Calculates a grade component (CS or Grade) based on given scores and weights."""
    class_standing = (weight_hoa * hoa) + (weight_quiz * quiz) + (weight_assignment * assignment)
    grade = (weight_exam * exam) + (weight_exam * class_standing)  #exam weight is also 50%
    return grade


def calculate_weighted_average(grade1, grade2, weight1, weight2):
    """Calculates a weighted average of two grades."""
    return (weight1 * grade1) + (weight2 * grade2)


def convert_to_tip_grade(final_grade):
    """Converts the final grade to the T.I.P. numerical grade equivalent."""
    if 94 <= final_grade <= 100:
        return 1.00
    elif 88.5 <= final_grade <= 93.99:
        return 1.25
    elif 83 <= final_grade <= 88.49:
        return 1.50
    elif 77.5 <= final_grade <= 82.99:
        return 1.75
    elif 72 <= final_grade <= 77.49:
        return 2.00
    elif 65.5 <= final_grade <= 71.99:
        return 2.25
    elif 61 <= final_grade <= 65.49:
        return 2.50
    elif 55.5 <= final_grade <= 60.99:
        return 2.75
    elif 50 <= final_grade <= 55.49:
        return 3.00
    elif 0 <= final_grade <= 49.99:
        return 5.00  # 5.00 for Failed (0-49.99)
    else:
        return "Invalid Grade"  # Cases of grades outside the defined range


def get_descriptive_rating(final_grade):
    """Gets the descriptive rating based on the final grade."""
    if 90 <= final_grade <= 100:
        return "Excellent"
    elif 85 <= final_grade <= 89.99:
        return "Superior"
    elif 80 <= final_grade <= 84.99:
        return "Meritorious"
    elif 75 <= final_grade <= 79.99:
        return "Very Good"
    elif 70 <= final_grade <= 74.99:
        return "Good"
    elif 65 <= final_grade <= 69.99:
        return "Very Satisfactory"
    elif 60 <= final_grade <= 64.99:
        return "Satisfactory"
    elif 55 <= final_grade <= 59.99:
        return "Fair"
    elif 50 <= final_grade <= 54.99:
        return "Passing"
    elif 40 <= final_grade <= 49.99:  # Incomplete based
        return "Incomplete"
    elif 0 <= final_grade <= 39.99:  # range for Failed.
        return "Failed"
    else:
        return "Invalid Grade"




num_students = int(input("Enter the number of students: "))  # the number of students

for student in range(num_students):
    print(f"\n--- Student {student+1} ---")
    name = input("Enter student name: ")

    # Grades computation per term
    prelim_exam = float(input("Enter prelim exam score: "))
    prelim_hoa = float(input("Enter average prelim HOA score: "))
    prelim_quiz = float(input("Enter average prelim quiz score: "))
    prelim_assignment = float(input("Enter average prelim assignment score: "))

    midterm_exam = float(input("Enter midterm exam score: "))
    midterm_hoa = float(input("Enter average midterm HOA score: "))
    midterm_quiz = float(input("Enter average midterm quiz score: "))
    midterm_assignment = float(input("Enter average midterm assignment score: "))

    final_exam = float(input("Enter final exam score: "))
    final_hoa = float(input("Enter average final HOA score: "))
    final_quiz = float(input("Enter average final quiz score: "))
    final_assignment = float(input("Enter average final assignment score: "))

    # Calculation of Prelim Grade
    prelim_grade = calculate_grade(prelim_exam, prelim_hoa, prelim_quiz, prelim_assignment, 0.5, 0.5, 0.3, 0.2)

    # Calculation of Midterm Grade
    midterm_cs = calculate_grade(midterm_exam, midterm_hoa, midterm_quiz, midterm_assignment, 0.5, 0.5, 0.3, 0.2)
    midterm_grade = calculate_weighted_average(prelim_grade, midterm_cs, 1/3, 2/3)

    # Calculation of Final Grade
    final_cs = calculate_grade(final_exam, final_hoa, final_quiz, final_assignment, 0.5, 0.5, 0.3, 0.2)
    final_grade = calculate_weighted_average(midterm_grade, final_cs, 1/3, 2/3)


    print("\n--- Final Grade Calculation ---")
    print("Prelim Grade:", prelim_grade)
    print("Midterm Grade:", midterm_grade)
    print("Final Grade:", final_grade)

    tip_grade = convert_to_tip_grade(final_grade)
    print("T.I.P. Grade:", tip_grade)

    descriptive_rating = get_descriptive_rating(final_grade)
    print("Descriptive Rating:", descriptive_rating)
# Out:
# Enter the number of students: 3
#
# --- Student 1 ---
# Enter student name: Miguel Joshua R. Samonte
# Enter prelim exam score: 50
# Enter average prelim HOA score: 90
# Enter average prelim quiz score: 60
# Enter average prelim assignment score: 80
# Enter midterm exam score: 50
# Enter average midterm HOA score: 80
# Enter average midterm quiz score: 50
# Enter average midterm assignment score: 90
# Enter final exam score: 40
# Enter average final HOA score: 85
# Enter average final quiz score: 50
# Enter average final assignment score: 90
#
# --- Final Grade Calculation ---
# Prelim Grade: 64.5
# Midterm Grade: 62.5
# Final Grade: 59.33333333333333
# T.I.P. Grade: 2.75
# Descriptive Rating: Fair
#
# --- Student 2 ---
# Enter student name: Rephnyl Jay Jatico
# Enter prelim exam score:  50
# Enter average prelim HOA score: 60
# Enter average prelim quiz score: 70
# Enter average prelim assignment score: 80
# Enter midterm exam score: 80
# Enter average midterm HOA score: 70
# Enter average midterm quiz score: 60
# Enter average midterm assignment score: 50
# Enter final exam score:  60
# Enter average final HOA score: 70
# Enter average final quiz score: 80
# Enter average final assignment score: 90
#
# --- Final Grade Calculation ---
# Prelim Grade: 58.5
# Midterm Grade: 67.16666666666666
# Final Grade: 68.05555555555554
# T.I.P. Grade: 2.25
# Descriptive Rating: Very Satisfactory
#
# --- Student 3 ---
# Enter student name: Rodge Canlapan
# Enter prelim exam score: 70
# Enter average prelim HOA score: 90
# Enter average prelim quiz score: 70
# Enter average prelim assignment score: 95
# Enter midterm exam score: 68
# Enter average midterm HOA score: 90
# Enter average midterm quiz score: 60
# Enter average midterm assignment score: 93
# Enter final exam score: 50
# Enter average final HOA score: 90
# Enter average final quiz score: 62
# Enter average final assignment score: 93
#
# --- Final Grade Calculation ---
# Prelim Grade: 77.5
# Midterm Grade: 75.69999999999999
# Final Grade: 69.29999999999998
# T.I.P. Grade: 2.25
# Descriptive Rating: Very Satisfactory
